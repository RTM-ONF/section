# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

from section import Section

# %%
df = pd.read_csv("../dataset/section_bis.txt",
                 delimiter="\t",
                 decimal=".")

# %%
section = Section()
section.from_df(df, x_field="X", z_field="Z")
# Out:
# True

# %%
section.xz
# Out:
# [(0.0, 548.6),
#  (1.07, 548.6),
#  (2.13, 548.62),
#  (3.2, 548.21),
#  (4.27, 547.25),
#  (5.33, 546.43),
#  (6.4, 545.76),
#  (7.47, 545.5),
#  (8.53, 545.22),
#  (9.6, 544.98),
#  (10.67, 544.77),
#  (11.73, 544.86),
#  (12.8, 545.16),
#  (13.87, 545.76),
#  (14.93, 546.17),
#  (16.0, 546.77),
#  (17.07, 547.23),
#  (18.13, 547.71),
#  (19.2, 548.29),
#  (20.27, 548.92),
#  (21.33, 549.55),
#  (22.4, 550.38),
#  (23.47, 550.84),
#  (24.54, 550.42),
#  (25.6, 550.38),
#  (26.67, 550.36)]

# %%
fig, ax = plt.subplots()
ax.set_aspect("equal")
ax.plot(section.x, section.z)
for line in section.water_lines(altitude=548.57):
    ax.plot([x for x, z in line], [z for x, z in line], color="Red")
plt.show()

# %%
min(section.z)
# Out:
# 544.77

# %%
section.ferguson(548., 0.05, 0.05)
# Out:
# 328.84691528263517

# %%
altitudes = np.arange(min(section.z), max(section.z), 0.1)
if max(section.z) not in altitudes:
    altitudes = np.append(altitudes, max(section.z))

# %%
altitudes
# Out:
# array([544.77, 544.87, 544.97, 545.07, 545.17, 545.27, 545.37, 545.47,
#        545.57, 545.67, 545.77, 545.87, 545.97, 546.07, 546.17, 546.27,
#        546.37, 546.47, 546.57, 546.67, 546.77, 546.87, 546.97, 547.07,
#        547.17, 547.27, 547.37, 547.47, 547.57, 547.67, 547.77, 547.87,
#        547.97, 548.07, 548.17, 548.27, 548.37, 548.47, 548.57, 548.67,
#        548.77, 548.87, 548.97, 549.07, 549.17, 549.27, 549.37, 549.47,
#        549.57, 549.67, 549.77, 549.87, 549.97, 550.07, 550.17, 550.27,
#        550.37, 550.47, 550.57, 550.67, 550.77, 550.84])

# %%
results = {
    "heights" : [],
    "discharges" : []
}

dh = 0.1
heights = np.arange(0., max(section.z)-min(section.z), dh)
if max(section.z)-min(section.z) not in heights:
    heights = np.append(heights, max(section.z)-min(section.z))

for height in heights:
    Q = section.ferguson(min(section.z) + height, 0.05, 0.05))
    if Q:
        results["heights"].append(float(height))
        results["discharges".append(discharge)
# Out:
# 0.0 None
# 0.1 0.032211087681293986
# 0.2 0.3095172267380639
# 0.30000000000000004 0.9758892466401115
# 0.4 2.112355015906309
# 0.5 3.8528500198602855
# 0.6000000000000001 6.151166909678645
# 0.7000000000000001 9.012879813475678
# 0.8 12.440049478891845
# 0.9 16.4875357338599
# 1.0 21.236126056645674
# 1.1 26.954085062995578
# 1.2000000000000002 33.3477330352394
# 1.3 40.43155504070316
# 1.4000000000000001 48.22126664153828
# 1.5 56.979572293207355
# 1.6 66.44369447796271
# 1.7000000000000002 76.66858263814478
# 1.8 87.67643778216181
# 1.9000000000000001 99.39992556638882
# 2.0 111.84612467636563
# 2.1 124.71973410362465
# 2.2 138.36291408113786
# 2.3000000000000003 152.78955528829084
# 2.4000000000000004 168.01357930242528
# 2.5 184.11035811717252
# 2.6 201.1712505347616
# 2.7 219.04791296771808
# 2.8000000000000003 237.75162788686015
# 2.9000000000000004 257.29373850814056
# 3.0 277.9058451053993
# 3.1 299.50509833864345
# 3.2 321.9481866152348
# 3.3000000000000003 345.2435202849388
# 3.4000000000000004 369.3996177081272
# 3.5 393.30861433095765
# 3.6 417.61671698214803
# 3.7 442.9886765494601
# 3.8000000000000003 469.4034702893188
# 3.9000000000000004 None
# 4.0 None
# 4.1000000000000005 None
# 4.2 None
# 4.3 None
# 4.4 None
# 4.5 None
# 4.6000000000000005 None
# 4.7 None
# 4.800000000000001 None
# 4.9 None
# 5.0 None
# 5.1000000000000005 None
# 5.2 None
# 5.300000000000001 None
# 5.4 None
# 5.5 None
# 5.6000000000000005 None
# 5.7 None
# 5.800000000000001 None
# 5.9 None
# 6.0 None
# 6.07000000000005 None
